# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("data_csv.csv")
plt.figure(figsize=(10,3))
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("data_csv.csv")
plt.figure(figsize=(10,7))
x=data["Value"]
plt.hist(x,bins=30,color="green")
plt.xlabel("Value")
plt.xlabel("Year")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("data_csv.csv")
data.plot(kind="scatter",x="Value",y="Year")
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("data_csv.csv")
plt.plot(data["Country Code"],"g--")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("data_csv.csv")
print(data.head(10))
# Out:
#                                     Country Name Country Code  Year  Value
# 0                                     Arab World          ARB  2017    310
# 1                         Caribbean small states          CSS  2017     76
# 2                 Central Europe and the Baltics          CEB  2017    133
# 3                     Early-demographic dividend          EAR  2017   1727
# 4                            East Asia & Pacific          EAS  2017   1166
# 5    East Asia & Pacific (excluding high income)          EAP  2017    787
# 6     East Asia & Pacific (IDA & IBRD countries)          TEA  2017    755
# 7                                      Euro area          EMU  2017    213
# 8                          Europe & Central Asia          ECS  2017    678
# 9  Europe & Central Asia (excluding high income)          ECA  2017    356
